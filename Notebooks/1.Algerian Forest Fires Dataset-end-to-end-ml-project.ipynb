# %% [markdown]
# ## Algerian Forest Fires Dataset

# %% [markdown]
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attribues and 1 output attribue (class)
# The 244 instances have been classified into fire (138 classes) and not fire (106 classes) classes.
#
# Dataset link: https://archive.ics.uci.edu/dataset/547/algerian+forest+fires+dataset
#
# ## Variable Information
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
#
# #### Weather data observations
#
# 2. Temp : temperature noon (temperature max)  in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
#
# #### FWI Components
#
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system:  7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %% [markdown]
# ## 1. UNDERSTAND THE GIVEN TASK
#
# 1. Do prooper EDA on the dataset and make insights
# 2. Then perform the necessary preprocessing steps
#
#
# ## 2. DATA COLLECTION AND UNDERSTANDING
#
# I used dataset on Algerian Forest Fires Dataset from UCI.The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.The timeline of this dataset is from June 2012 to September 2012.
#
# In this problem statement, we will explore the data and make insights for that data
#
# ## 3. DATA EXPLORATION
#
# * In this step, we will apply Exploratory Data Analysis (EDA) to extract insights from the data set to know which features have contributed more in predicting Forest fire by performing Data Analysis using Pandas and Data visualization using Matplotlib & Seaborn. It is always a good practice to understand the data first and try to gather as many insights from it.
#
#
# Below are tasks to be performed in EDA:
#
# **1. Importing Libraries**
#
#
# **2. Data Cleaning for EDA Report**
#
# **3. Exploratory Data Analysis (EDA) on all Features**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df=pd.read_csv("Algerian_forest.csv")

# %%
df.head()
# Out:
#                                                                   Bejaia Region Dataset
# day month year Temperature  RH  Ws Rain  FFMC DMC DC  ISI BUI FWI              Classes
# 01  06    2012 29          57  18  0     65.7 3.4 7.6 1.3 3.4 0.5            not fire
# 02  06    2012 29          61  13  1.3   64.4 4.1 7.6 1   3.9 0.4            not fire
# 03  06    2012 26          82  22  13.1  47.1 2.5 7.1 0.3 2.7 0.1            not fire
# 04  06    2012 25          89  13  2.5   28.6 1.3 6.9 0   1.7 0              not fire

# %%
df=pd.read_csv("Algerian_forest.csv",header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (246, 14)

# %% [markdown]
# ### Data Checks to perform
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ## Insights:
#
# - There are less number of null values (~2) present in target variable and 1 missing value in the remaining features except day feature

# %% [markdown]
# ### Checking duplicates

# %%
df.duplicated().sum() # No duplicate values
# Out:
# 0

# %% [markdown]
# ### Check data type

# %%
for i in df.columns:
    print(df[i].dtypes)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %% [markdown]
# ### Check the number of unique values of each column

# %%
# All independent features are numerical features so no need to find the unique values

# %% [markdown]
# ## Check the dataset has null values

# %%
df[df.isnull().any(axis=1)]

# .any(axis=1) method is used to determine whether there are any missing values (null or NaN) along the rows (across columns) 
# of the dataset. This is a useful technique when you want to identify rows that contain at least one missing value.
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 122th index,
# we can make a new column based on the Region
#
#  **1 : "Bejaia Region Dataset"**
#
#  **2 : "Sidi-Bel Abbes Region Dataset"**

# %%
df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# 1    0.4   not fire          1
# 2    0.1   not fire          1
# 3      0   not fire          1
# 4    0.5   not fire          1
# ..   ...           ...     ...
# 241  6.5       fire          2
# 242    0   not fire          2
# 243  0.2   not fire          2
# 244  0.7   not fire          2
# 245  0.5  not fire           2
#
# [246 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
# Remove null or na values rows

df.dropna()

df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# 1    0.4   not fire          1
# 2    0.1   not fire          1
# 3      0   not fire          1
# 4    0.5   not fire          1
# ..   ...           ...     ...
# 241  6.5       fire          2
# 242    0   not fire          2
# 243  0.2   not fire          2
# 244  0.7   not fire          2
# 245  0.5  not fire           2
#
# [246 rows x 15 columns]

# %%
df=df.dropna().reset_index(drop=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# 1    0.4   not fire          1
# 2    0.1   not fire          1
# 3      0   not fire          1
# 4    0.5   not fire          1
# ..   ...           ...     ...
# 239  6.5       fire          2
# 240    0   not fire          2
# 241  0.2   not fire          2
# 242  0.7   not fire          2
# 243  0.5  not fire           2
#
# [244 rows x 15 columns]

# %% [markdown]
# In the line of code df = df.dropna().reset_index(drop=True), the drop=True parameter is part of the reset_index method in Pandas.
#
# Here's a breakdown of what this line does:
#
# df.dropna(): This method removes any rows from the DataFrame (df) that contain missing values (NaN). It effectively drops rows where at least one element is missing.
#
# .reset_index(drop=True): After dropping the NaN values, this part of the code resets the index of the DataFrame. The drop=True parameter is used to discard the old index column and not add it as a new column in the DataFrame. Without drop=True, the old index would become a new column in the DataFrame.
#
# So, the overall effect of the line is to remove rows containing missing values from the DataFrame (df) and reset the index. The DataFrame with missing values removed and the index reset is then assigned back to the variable df.

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         2

# %% [markdown]
# **Null and other unwanted rows are removed**

# %%
# Drop the 122th row 

df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[120:125]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 120  29    09  2012          26  80  16   1.8  47.4  2.9  7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9  7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
# 123  02    06  2012          30  73  13     4  55.7  2.7  7.8  0.6  2.9  0.2
# 124  03    06  2012          29  80  14     2  48.7  2.2  7.6  0.3  2.6  0.1
#
#        Classes    Region
# 120  not fire          1
# 121  not fire          1
# 122  not fire          2
# 123  not fire          2
# 124  not fire          2

# %%
df["Classes  "].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %% [markdown]
# **Some column names were misspaced so we can fix it**

# %%
# List out column names to check
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %% [markdown]
# Looks like the values were misspaced so we can use **str.strip()** method

# %%
# Spaces were fixed in the column names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# **Changing the required columns as integer data type**

# %%
df[['month', 'day', 'year', 'Temperature','RH', 'Ws']] = df[['month', 'day', 'year', 'Temperature','RH', 'Ws']].astype(int)

# %% [markdown]
# **Changing the other columns to Float data type**

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']
for i in objects:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
# Final datatypes check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%  \
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# BUI          243.0    16.690535  14.228421     1.1     6.00    12.4    22.65
# FWI          243.0     7.035391   7.440568     0.0     0.70     4.2    11.45
# Region       243.0     1.497942   0.501028     1.0     1.00     1.0     2.00
#
#                 max
# day            31.0
# month           9.0
# year         2012.0
# Temperature    42.0
# RH             90.0
# Ws             29.0
# Rain           16.8
# FFMC           96.0
# DMC            65.9
# DC            220.4
# ISI            19.0
# BUI            68.0
# FWI            31.1
# Region          2.0

# %% [markdown]
# **Data Cleaning in target variable**

# %%
df["Classes"].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %% [markdown]
# Looks like the values were misspaced so we can use **str.strip()** method

# %%
# Strip mispaced values
df.Classes = df.Classes.str.strip()

# Or we can use apply() method

# %%
df.Classes.value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %% [markdown]
# #### Region 1 (Bejaia Region)

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# 1    0.4  not fire       1
# 2    0.1  not fire       1
# 3    0.0  not fire       1
# 4    0.5  not fire       1
# ..   ...       ...     ...
# 238  6.5      fire       2
# 239  0.0  not fire       2
# 240  0.2  not fire       2
# 241  0.7  not fire       2
# 242  0.5  not fire       2
#
# [243 rows x 15 columns]

# %%
df[df.Region==1]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# 1    0.4  not fire       1
# 2    0.1  not fire       1
# 3    0.0  not fire       1
# 4    0.5  not fire       1
# ..   ...       ...     ...
# 117  1.7  not fire       1
# 118  4.1      fire       1
# 119  0.9  not fire       1
# 120  0.1  not fire       1
# 121  0.1  not fire       1
#
# [122 rows x 15 columns]

# %%
df[df.Region==2]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 122    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 123    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 124    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 125    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 126    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 122  0.2  not fire       2
# 123  0.2  not fire       2
# 124  0.1  not fire       2
# 125  1.0  not fire       2
# 126  0.9  not fire       2
# ..   ...       ...     ...
# 238  6.5      fire       2
# 239  0.0  not fire       2
# 240  0.2  not fire       2
# 241  0.7  not fire       2
# 242  0.5  not fire       2
#
# [121 rows x 15 columns]

# %%
df[df.Region==2].reset_index()
# Out:
#      index  day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  \
# 0      122    1      6  2012           32  71  12   0.7  57.1   2.5   8.2
# 1      123    2      6  2012           30  73  13   4.0  55.7   2.7   7.8
# 2      124    3      6  2012           29  80  14   2.0  48.7   2.2   7.6
# 3      125    4      6  2012           30  64  14   0.0  79.4   5.2  15.4
# 4      126    5      6  2012           32  60  14   0.2  77.1   6.0  17.6
# ..     ...  ...    ...   ...          ...  ..  ..   ...   ...   ...   ...
# 116    238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5
# 117    239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0
# 118    240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9
# 119    241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2
# 120    242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI   Classes  Region
# 0    0.6   2.8  0.2  not fire       2
# 1    0.6   2.9  0.2  not fire       2
# 2    0.3   2.6  0.1  not fire       2
# 3    2.2   5.6  1.0  not fire       2
# 4    1.8   6.5  0.9  not fire       2
# ..   ...   ...  ...       ...     ...
# 116  4.5  16.9  6.5      fire       2
# 117  0.1   6.2  0.0  not fire       2
# 118  0.4   3.4  0.2  not fire       2
# 119  1.7   5.1  0.7  not fire       2
# 120  1.2   4.8  0.5  not fire       2
#
# [121 rows x 16 columns]

# %%
# making the correct index values 

df[df.Region==2].reset_index(drop=True)

# remove drop=True and observe the output (see the above output)

# The drop=True parameter is used to discard the old index column and not add it as a new column in the DataFrame. 
# Without drop=True, the old index would become a new column in the DataFrame.
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 1      2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 2      3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 3      4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 4      5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 116   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 117   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 118   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 119   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 120   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 0    0.2  not fire       2
# 1    0.2  not fire       2
# 2    0.1  not fire       2
# 3    1.0  not fire       2
# 4    0.9  not fire       2
# ..   ...       ...     ...
# 116  6.5      fire       2
# 117  0.0  not fire       2
# 118  0.2  not fire       2
# 119  0.7  not fire       2
# 120  0.5  not fire       2
#
# [121 rows x 15 columns]

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# 1    0.4  not fire       1
# 2    0.1  not fire       1
# 3    0.0  not fire       1
# 4    0.5  not fire       1
# ..   ...       ...     ...
# 238  6.5      fire       2
# 239  0.0  not fire       2
# 240  0.2  not fire       2
# 241  0.7  not fire       2
# 242  0.5  not fire       2
#
# [243 rows x 15 columns]

# %%
df.to_csv("algerian_forest_cleaned.csv",index=False) # if we didn't declared the index=True then a new column will be created

# %%
pd.read_csv("algerian_forest_cleaned.csv")
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# 1    0.4  not fire       1
# 2    0.1  not fire       1
# 3    0.0  not fire       1
# 4    0.5  not fire       1
# ..   ...       ...     ...
# 238  6.5      fire       2
# 239  0.0  not fire       2
# 240  0.2  not fire       2
# 241  0.7  not fire       2
# 242  0.5  not fire       2
#
# [243 rows x 15 columns]

# %%
df1=pd.read_csv("algerian_forest_cleaned.csv")

# %%
df1
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# 1    0.4  not fire       1
# 2    0.1  not fire       1
# 3    0.0  not fire       1
# 4    0.5  not fire       1
# ..   ...       ...     ...
# 238  6.5      fire       2
# 239  0.0  not fire       2
# 240  0.2  not fire       2
# 241  0.7  not fire       2
# 242  0.5  not fire       2
#
# [243 rows x 15 columns]

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df1.isnull().any(axis=1).sum()
# Out:
# 0

# %% [markdown]
# # Explorartory Data Analysis

# %%
#Droping Year features
df1 = df.drop(['day','month','year'], axis=1)

# %%
# Small concept to understand the np.where function

arr=np.array([1,2,3,4,5])

# %%
np.where(arr>3,"s","o")
# Out:
# array(['o', 'o', 'o', 's', 's'], dtype='<U1')

# %%
df1["Classes"].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
# Encoding Not fire as 0 and Fire as 1

df1["Classes"]=np.where(df1["Classes"]=="not fire",0,1)

# %%
df1["Classes"].unique()
# Out:
# array([0, 1])

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 238       2
# 239       2
# 240       2
# 241       2
# 242       2
#
# [243 rows x 12 columns]

# %%
df1["Classes"].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %% [markdown]
# **Visualization of Distribution**

# %%
# PLot density plot for all features
plt.style.use('seaborn')
df1.hist(bins=50, figsize=(20,15), ec = 'g')
plt.show()

# %%
for i in df1.columns:
    if i!="Classes":
        sns.histplot(df1[i],bins=50,color="g",kde=True)
        plt.show()

# %%
# Percentage for PieChart
percentage = df1.Classes.value_counts(normalize=True)*100
print(percentage)
# Out:
# 1    56.378601
# 0    43.621399
# Name: Classes, dtype: float64

# %%
# Our analyzation

df1.Classes.value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
137/len(df1)
# Out:
# 0.5637860082304527

# %%
106/len(df1)
# Out:
# 0.43621399176954734

# %% [markdown]
# **Charts**

# %%
#plotting PieChart

classeslabels = ["FIRE", "NOT FIRE"]
plt.figure(figsize =(12, 7))
plt.pie(percentage,labels = classeslabels,autopct='%1.1f%%')
plt.title ("Pie Chart of Classes", fontsize = 15)
plt.show()

# %% [markdown]
# **Checking Multicollinearity**

# %%
df1.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# Region          0.269555 -0.402682 -0.181160 -0.040013  0.222241  0.192089
#
#                    DC       ISI       BUI       FWI   Classes    Region
# Temperature  0.376284  0.603871  0.459789  0.566670  0.516015  0.269555
# RH          -0.226941 -0.686667 -0.353841 -0.580957 -0.432161 -0.402682
# Ws           0.079135  0.008532  0.031438  0.032368 -0.069964 -0.181160
# Rain        -0.298023 -0.347484 -0.299852 -0.324422 -0.379097 -0.040013
# FFMC         0.507397  0.740007  0.592011  0.691132  0.769492  0.222241
# DMC          0.875925  0.680454  0.982248  0.875864  0.585658  0.192089
# DC           1.000000  0.508643  0.941988  0.739521  0.511123 -0.078734
# ISI          0.508643  1.000000  0.644093  0.922895  0.735197  0.263197
# BUI          0.941988  0.644093  1.000000  0.857973  0.586639  0.089408
# FWI          0.739521  0.922895  0.857973  1.000000  0.719216  0.197102
# Classes      0.511123  0.735197  0.586639  0.719216  1.000000  0.162347
# Region      -0.078734  0.263197  0.089408  0.197102  0.162347  1.000000

# %%
plt.figure(figsize=(12,6))

sns.heatmap(df1.corr(),annot=True)

plt.show()

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 238       2
# 239       2
# 240       2
# 241       2
# 242       2
#
# [243 rows x 12 columns]

# %% [markdown]
# #### Canadian Forest Fire Weather Index (FWI) System
# This column can be considered for Regression problem

# %%
#Boxplot
sns.boxplot(df['FWI'], color= 'red',orient="h")
plt.xlabel("FWI")
plt.show()

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# 1    0.4  not fire       1
# 2    0.1  not fire       1
# 3    0.0  not fire       1
# 4    0.5  not fire       1
# ..   ...       ...     ...
# 238  6.5      fire       2
# 239  0.0  not fire       2
# 240  0.2  not fire       2
# 241  0.7  not fire       2
# 242  0.5  not fire       2
#
# [243 rows x 15 columns]

# %% [markdown]
# ### **Monthwise Fire Analysis**

# %%
dftemp=df1[df1["Region"]==1]
plt.subplots(figsize=(10,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data= df,palette="Set2",ec="black")
plt.title('Fire Analysis Month wise for Bejaia Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Months',weight="bold")
plt.legend(loc='upper right')
plt.xticks(np.arange(0,4),['June','July', 'August', 'September'])
plt.grid(alpha = 0.5,axis = 'y')
plt.show()

# %%
dftemp= df.loc[df['Region']== 2]
plt.subplots(figsize=(10,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data= df,ec = 'black', palette= 'Set2')
plt.title('Fire Analysis Month wise for Sidi-Bel Abbes Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Months', weight= 'bold')
plt.legend(loc='upper right')
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.grid(alpha = 0.5,axis = 'y')
plt.show()

# %% [markdown]
# * Its observed that July and August had the most number of forest fires for both regions. And from the above plot of months, we can understand few things
#
# * Most of the fires happened in August and very high Fires happened in only 3 months - **June, July and August.**
#
# * Less Fires was on September

# %% [markdown]
# ### 3.5 Exploratory Data Analysis (EDA) on all Features

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 238       2
# 239       2
# 240       2
# 241       2
# 242       2
#
# [243 rows x 12 columns]

# %%
df1.groupby(["Temperature"])['Classes'].sum()
# Out:
# Temperature
# 22     0
# 24     0
# 25     0
# 26     1
# 27     1
# 28     3
# 29     5
# 30     7
# 31    16
# 32    12
# 33    15
# 34    16
# 35    22
# 36    20
# 37     8
# 38     2
# 39     5
# 40     3
# 42     1
# Name: Classes, dtype: int32

# %%
df1.groupby(["Temperature"],as_index=False)['Classes'].sum()

# as_index== False means It will not consider old index values , it will reset indexes for all
# Out:
#     Temperature  Classes
# 0            22        0
# 1            24        0
# 2            25        0
# 3            26        1
# 4            27        1
# 5            28        3
# 6            29        5
# 7            30        7
# 8            31       16
# 9            32       12
# 10           33       15
# 11           34       16
# 12           35       22
# 13           36       20
# 14           37        8
# 15           38        2
# 16           39        5
# 17           40        3
# 18           42        1

# %%
def barchart(feature,xlabel):
    plt.figure(figsize=[14,8])
    by_feature =  df1.groupby([feature], as_index=False)['Classes'].sum()
    ax = sns.barplot(x=feature, y="Classes", data=by_feature[[feature,'Classes']], estimator=sum)
    ax.set(xlabel=xlabel, ylabel='Fire Count')

# %%
barchart('Temperature','Temperature Max in Celsius degrees')

# %%
barchart('Rain', 'Rain in mm')

# %% [markdown]
# #### Fine Fuel Moisture Code (FFMC) index

# %%
barchart('Ws', 'Wind Speed in km/hr')

# %%
barchart('RH','Relative Humidity in %')

# %% [markdown]
# #### Weather System Report
# * **Temperature** Highest Fire counts happened between **30-37 degree Celsius**
# * **Rain** Highest Fire counts happened when there was no rain to very less rain ie. **0.0 to 0.3.**
# * **Wind Speed** highest Fire count happened when the wind speed were between **13 to 19 Km/hr.**
# * **Relative Humidity** highest fire count happened when the RH is between **50 to 80%.**

# %%
# pw skills code for box plot

dftemp = df1.drop(['Classes', 'Region'], axis=1)
fig = plt.figure(figsize =(12, 6))
ax = dftemp.boxplot()
ax.set_title("Boxplot of Given Dataset")
plt.show()

# %%
# my code for box plot

dftemp = df1.drop(['Classes', 'Region'], axis=1)
plt.figure(figsize=(12,6))
dftemp.boxplot()
plt.title("Box plot of given dftemp dataset")
plt.show()

# %%
dftemp = dftemp = df1.drop(['Region','Temperature','Rain','Ws','RH'], axis=1)
for feature in dftemp:
    sns.histplot(data = dftemp,x=feature, hue = 'Classes',kde=True)
    plt.legend(labels=['Fire','Not Fire'],loc="upper right")
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### REPORT
# #### Weather System Report
# * **Temperature** Highest Fire counts happened between **30-37 degree Celsius**
# * **Rain** Highest Fire counts happened when there was no rain to very less rain ie. **0.0 to 0.3.**
# * **Wind Speed** highest Fire count happened when the wind speed were between **13 to 19 Km/hr.**
# * **Relative Humidity** highest fire count happened when the RH is between **50 to 80%.**
#
#
# #### FWI System Components Report
# FWI (Canadian Forest Fire Weather Index)
# * **Fine Fuel Moisture Code (FFMC) index** which ranges between *28.6 to 92.5*,
#     here **above 75** has higher chance of Forest fires.
#
# * **Duff Moisture Code (DMC) index** which ranges between *1.1 to 65.9*,
#     here 1.1-10 has lower chance of Forest fires whereas above **10-30 DMC** has very high evidence of Forest fires in past.
#
# * **Drought Code (DC) index** which ranges between *7 to 220.4*,
#     here 0-25 is safe and has lower chance of Forest fires whereas range **above 25 DC** has higher chance of forest fires.
#
# * **Initial Spread Index (ISI) index** which ranges between *0 to 18*,
#     here 0-3 has lower Forest fires and **above 3 ISI** has higher chance of Forest fires.
#
# * **Buildup Index (BUI) index** which ranges between *1.1 to 68*,
#     here 1.1 to 10 has lower Forest fire chance and **above 10 BUI has** higher chance of forest fires.
#
# * **Fire Weather Index (FWI) Index** which ranges between *1 to 31.1*,
#     here 0-3 has lower chance of Forest fires and **3-25 FWI** has higher chance of forest fires.

# %%
## Let's use the algerian_forest_cleaned.csv which was created at line 38,39 to model our regression model (Multi-Linear, Ridge,
# Lasso,Ekastic net )

# %%
## Let's use another jupyter notebook to train our model on algerian_forest_cleaned.csv, Thanks for visiting.

# %% [markdown]
# ## Summary

# %% [markdown]
# 1. Performed the EDA and feature engineering and saved the algerian_forest_cleaned.csv file after done with data cleaning
# 2. Let's move forward to train the different type of regression models
